# %% [markdown]
# <a href="https://colab.research.google.com/github/iampaapa/microprocessor-project/blob/main/assembler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#take in a file
#parse the file sentence by sentence
#change that code into binary
#write it into a new file
#save it as txt file

#makes a list and generates a list of all the lines in that txt file.
linesList = []

with open('/content/ASMcode.txt') as f:
    linesList = f.readlines()

f.close() #closes the file

#create a new txt file. open it for writing
someVar = open("/content/binaryCode.txt", "w")


def aluDoubleInputFunction(binCodeLine, newVal):
  functionsAndEquivalents = {"ADD":"10000000", "ORR":"10000001", "EOR":"10000010", 
                           "SHL":"10000011", "SHR":"10000100", "ROL":"10000101", 
                           "ROR":"10000110", "DIV":"10000111", "MOD":"10001000", 
                           "INC":"10001001", "DEC":"10001010", "MUL":"10001011", 
                           "ADDc":"10001100", "AND":"10001101", "SUBb":"10001110", 
                           "SUB":"10001111", "LDR":"00100000", "STR":"00100001", 
                           "DAT":"00100010", "BBR":"00100011", "BBI":"00100100", 
                           "JMP":"00010101", "JMPM":"00010101", "CLF":"00010110", 
                           "HALT":"00011111"}

  registersAndEquivalents = {"R1":"0000", "R2":"0001", "R3":"0010", "R4":"0011"}

  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  #so, we are left with registers or empty space

  if someNewVal == "":
    #throw an HALT exception and close the file
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  else:
    #5 characters remaining RA,RB
    if someNewVal[1] == "1":
      if someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R4"]
        someVar.write(binCodeLine)
        someVar.write("\n")
  #second
    elif someNewVal[1] == "2":
      if someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R4"]
        someVar.write(binCodeLine)
        someVar.write("\n")
    #third
    elif someNewVal[1] == "3":
      if someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R4"]
        print(binCodeLine)
        someVar.write(binCodeLine)
        someVar.write("\n")
      #fourth
    elif someNewVal[1] == "4":
      if someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")

def aluSingleInputFunction(binCodeLine, newVal):
  functionsAndEquivalents = {"ADD":"10000000", "ORR":"10000001", "EOR":"10000010", 
                           "SHL":"10000011", "SHR":"10000100", "ROL":"10000101", 
                           "ROR":"10000110", "DIV":"10000111", "MOD":"10001000", 
                           "INC":"10001001", "DEC":"10001010", "MUL":"10001011", 
                           "ADDc":"10001100", "AND":"10001101", "SUBb":"10001110", 
                           "SUB":"10001111", "LDR":"00100000", "STR":"00100001", 
                           "DAT":"00100010", "BBR":"00100011", "BBI":"00100100", 
                           "JMP":"00010101", "JMPM":"00010101", "CLF":"00010110", 
                           "HALT":"00011111"}

  registersAndEquivalents = {"R1":"0000", "R2":"0001", "R3":"0010", "R4":"0011"}

  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  #so, we are left with registers or empty space

  if someNewVal == "":
    #throw an HALT exception and close the file
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  else:
    #5 characters remaining RA,RB
    if someNewVal[1] == "1":
      if someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R1"] + registersAndEquivalents["R4"]
        someVar.write(binCodeLine)
        someVar.write("\n")
  #second
    elif someNewVal[1] == "2":
      if someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R2"] + registersAndEquivalents["R4"]
        someVar.write(binCodeLine)
        someVar.write("\n")
    #third
    elif someNewVal[1] == "3":
      if someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "4":
        binCodeLine = binCodeLine + registersAndEquivalents["R3"] + registersAndEquivalents["R4"]
        print(binCodeLine)
        someVar.write(binCodeLine)
        someVar.write("\n")
      #fourth
    elif someNewVal[1] == "4":
      if someNewVal[4] == "2":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R2"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "3":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R3"]
        someVar.write(binCodeLine)
        someVar.write("\n")
      elif someNewVal[4] == "1":
        binCodeLine = binCodeLine + registersAndEquivalents["R4"] + registersAndEquivalents["R1"]
        someVar.write(binCodeLine)
        someVar.write("\n")

def dataTransferFunction(binCodeLine, newVal):
  functionsAndEquivalents = {"ADD":"10000000", "ORR":"10000001", "EOR":"10000010", 
                           "SHL":"10000011", "SHR":"10000100", "ROL":"10000101", 
                           "ROR":"10000110", "DIV":"10000111", "MOD":"10001000", 
                           "INC":"10001001", "DEC":"10001010", "MUL":"10001011", 
                           "ADDc":"10001100", "AND":"10001101", "SUBb":"10001110", 
                           "SUB":"10001111", "LDR":"00100000", "STR":"00100001", 
                           "DAT":"00100010", "BBR":"00100011", "BBI":"00100100", 
                           "JMP":"00010101", "JMPM":"00010101", "CLF":"00010110", 
                           "HALT":"00011111"}

  registersAndEquivalents = {"R1":"0000", "R2":"0001", "R3":"0010", "R4":"0011"}

  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  zero_offset = "0000"
  #so, we are left with registers or empty space = rb

  if someNewVal == "":
    #throw an HALT exception and close the file
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  else:
    #2 characters remaining RB
    if someNewVal[1] == "1":
      binCodeLine = binCodeLine + zero_offset + registersAndEquivalents["R1"]
      someVar.write(binCodeLine)
      someVar.write("\n")
  #second
    elif someNewVal[1] == "2":
      binCodeLine = binCodeLine + zero_offset + registersAndEquivalents["R2"]
      someVar.write(binCodeLine)
      someVar.write("\n")
    #third
    elif someNewVal[1] == "3":
      binCodeLine = binCodeLine + zero_offset + registersAndEquivalents["R3"]
      someVar.write(binCodeLine)
      someVar.write("\n")
      #fourth
    elif someNewVal[1] == "4":
      binCodeLine = binCodeLine + zero_offset + registersAndEquivalents["R4"]
      someVar.write(binCodeLine)
      someVar.write("\n")

def noRegisterFunction(binCodeLine, newVal):
  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  zero_offset = "00000000"
  #so, we are left with empty space = rb

  if someNewVal == "":
    #fill it with the appropriate offsets
    binCodeLine = binCodeLine + zero_offset
    someVar.write(binCodeLine)
    someVar.write("\n")
    someVar.close()

def jumpOneFunction(binCodeLine, newVal):
  functionsAndEquivalents = {"ADD":"10000000", "ORR":"10000001", "EOR":"10000010", 
                           "SHL":"10000011", "SHR":"10000100", "ROL":"10000101", 
                           "ROR":"10000110", "DIV":"10000111", "MOD":"10001000", 
                           "INC":"10001001", "DEC":"10001010", "MUL":"10001011", 
                           "ADDc":"10001100", "AND":"10001101", "SUBb":"10001110", 
                           "SUB":"10001111", "LDR":"00100000", "STR":"00100001", 
                           "DAT":"00100010", "BBR":"00100011", "BBI":"00100100", 
                           "JMP":"00010101", "JMPM":"00010101", "CLF":"00010110", 
                           "HALT":"00011111"}

  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  #so, we are left with our carry condition

  if someNewVal == "":
    #throw an HALT exception and close the file
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  else:
    #1 characters remaining the carry condition
    characterCondition = {"C":"10000000", "G": "01000000", "E": "00100000", "Z": "00010000", "UD": "00001000", "O": "00000100", "UF": "00000010", "L": "00000001"}
    
    for x in characterCondition:
      if someNewVal[1] == characterCondition[x]:
        binCodeLine = binCodeLine + characterCondition[x]
        someVar.write(binCodeLine)
        someVar.write("\n")
      break;

def jumpMultipleFunction(binCodeLine, newVal):
  someNewVal = newVal.replace(currentInstruction, "")
  someNewVal = someNewVal.strip().replace(" ", "")
  #so, we are left with our carry conditions

  if someNewVal == "":
    #throw an HALT exception and close the file
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  else:
    #x characters remaining the carry condition
    C_BIT=0 
    G_BIT=0
    E_BIT=0
    Z_BIT=0
    Ud_BIT=0
    O_BIT=0
    Uf_BIT=0
    L_BIT = 0
    
    characterCondition = {"C":"10000000", "G": "01000000", "E": "00100000", "Z": "00010000", "UD": "00001000", "O": "00000100", "UF": "00000010", "L": "00000001"}
    someNewVal = someNewVal.rstrip(someNewVal[-1]) #removes the last character == semi-colon.
    #separate the remaining strings into a list
    carry_list = someNewVal.split(",") #list holding all our carry bits

    for x in carry_list:
      finalVal = "0"
      #find the correct key corresponding to the carry_list[x]
      if(x.upper() == "C"):
          C_BIT = C_BIT+1
      elif(x.upper() == "G"):
          G_BIT = G_BIT+1
      elif(x.upper() == "E"):
          E_BIT = E_BIT+1
      elif(x.upper() == "Z"):
          Z_BIT = Z_BIT+1
      elif(x.upper() == "UD"):
          Ud_BIT = Ud_BIT+1
      elif(x.upper() == "O"):
          O_BIT = O_BIT+1
      elif(x.upper() == "UF"):
          Uf_BIT = Uf_BIT+1
      elif(x.upper() == "L"):
          L_BIT = L_BIT+1

      finalVal = resultant(C_BIT, G_BIT, E_BIT, Z_BIT, Ud_BIT, O_BIT, Uf_BIT, L_BIT)

      #clear the first two bits and clear till there are only 8 bits remaining

    binCodeLine = binCodeLine + finalVal
    someVar.write(binCodeLine)
    someVar.write("\n")

#main function actually starts from here

def resultant(C, G, E, Z, Ud, O, Uf, L):
  return (str(C)+str(G)+str(E)+str(Z)+str(Ud)+str(O)+str(Uf)+str(L))

#A dictionary of functions and their corresponding binary equivalents
functionsAndEquivalents = {"ADD":"10000000", "ORR":"10000001", "EOR":"10000010", 
                           "SHL":"10000011", "SHR":"10000100", "ROL":"10000101", 
                           "ROR":"10000110", "DIV":"10000111", "MOD":"10001000", 
                           "INC":"10001001", "DEC":"10001010", "MUL":"10001011", 
                           "ADDc":"10001100", "AND":"10001101", "SUBb":"10001110", 
                           "SUB":"10001111", "LDR":"00100000", "STR":"00100001", 
                           "DAT":"00100010", "BBR":"00100011", "BBI":"00100100", 
                           "JMP":"00010101", "JMPM":"00010101", "CLF":"00010110", 
                           "HALT":"00011111"}

registersAndEquivalents = {"R1":"0000", "R2":"0001", "R3":"0010", "R4":"0011"}

binCodeLine = ""
currentInstruction = ""

#parse the line and change that code into binary
for x in range(0, len(linesList)):
  #remove the spaces in between and around the string
  newVal = linesList[x]
  newVal.strip().replace(" ", "").upper()

  #find the function that is being used
  for i in functionsAndEquivalents:
    #find the occurence of the instruction in functionsAndEquivalents
    someThing = newVal.find(i)

    if someThing != -1:
      #that means an instruction is being used
      binCodeLine = ""
      binCodeLine = binCodeLine + functionsAndEquivalents[i]
      currentInstruction = i

      if currentInstruction == "ADD" or currentInstruction == "ORR" or currentInstruction == "EOR" or currentInstruction == "DIV" or currentInstruction == "MOD" or currentInstruction == "INC" or currentInstruction == "DEC" or currentInstruction == "MUL" or currentInstruction == "ADDc" or currentInstruction == "AND" or currentInstruction == "SUBb" or currentInstruction == "SUB":
        aluDoubleInputFunction(binCodeLine, newVal)

      elif currentInstruction == "SHL" or currentInstruction == "SHR" or currentInstruction == "ROL" or currentInstruction == "ROR":
        aluSingleInputFunction(binCodeLine, newVal)

      elif currentInstruction == "LDR" or currentInstruction == "STR":
        dataTransferFunction(binCodeLine, newVal)

      elif currentInstruction == "DAT" or currentInstruction == "BBR":
        dataTransferFunction(binCodeLine, newVal)

      elif currentInstruction == "BBI" or currentInstruction == "CLF" or currentInstruction == "HALT":
        noRegisterFunction(binCodeLine, newVal)

      elif currentInstruction == "JMP":
        jumpOneFunction(binCodeLine, newVal)

      elif currentInstruction == "JMPM":
        jumpMultipleFunction(binCodeLine, newVal)

  #the other types of instructions. work on them
  
  if binCodeLine == "":
    someVar.write(functionsAndEquivalents["HALT"])
    someVar.write("\n")
    someVar.close()
  

someVar.close() #closes the file
